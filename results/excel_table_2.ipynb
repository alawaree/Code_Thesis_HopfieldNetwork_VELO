# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import seaborn as sns
import re

# %%
project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    
print(project_root)
# Out:
# c:\Users\aurel\Documents\GitHub\Code_Thesis_GitHub\Code_Thesis_GitHub

# %%
import re

# Multiline string containing the text
data = """
619 tracks including       25 ghosts (  4.0%). Event average   4.0%
              velo :      512 from      622 ( 82.3%,  83.2%)       25 clones (  4.88%), purity: ( 99.02%,  99.04%),  hitEff: ( 88.68%,  88.72%)
              long :      145 from      153 ( 94.8%,  94.6%)       18 clones ( 12.41%), purity: ( 99.42%,  99.49%),  hitEff: ( 86.96%,  84.62%)
         long>5GeV :       65 from       70 ( 92.9%,  92.2%)        9 clones ( 13.85%), purity: ( 99.53%,  99.60%),  hitEff: ( 85.49%,  83.81%)
      long_strange :        8 from        8 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 97.50%,  97.50%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: (100.00%, 100.00%)
"""

# Extract data lines containing percentages
lines = data.split("\n")
data_lines = [line.strip() for line in lines if "%" in line]

# Extract and print the desired values
for line in data_lines:
    parts = re.findall(r"(\d+\.\d+)%\)", line)
    values = " ".join(parts)
    print(values)
# Out:
# 4.0
# 83.2 4.88 99.04 88.72
# 94.6 12.41 99.49 84.62
# 92.2 13.85 99.60 83.81
# 100.0 0.00 100.00 97.50
# 100.0 0.00 100.00 100.00

# %%
data = """
1005 tracks including       69 ghosts (  6.9%). Event average   6.8%
              velo :      808 from     1071 ( 75.4%,  77.3%)       59 clones (  7.30%), purity: ( 98.47%,  98.61%),  hitEff: ( 86.02%,  86.06%)
              long :      265 from      289 ( 91.7%,  94.2%)       37 clones ( 13.96%), purity: ( 98.60%,  98.56%),  hitEff: ( 82.90%,  81.98%)
         long>5GeV :      180 from      194 ( 92.8%,  94.4%)       24 clones ( 13.33%), purity: ( 98.29%,  98.31%),  hitEff: ( 83.65%,  82.58%)
      long_strange :        9 from       11 ( 81.8%,  97.0%)        0 clones (  0.00%), purity: ( 95.97%,  93.96%),  hitEff: ( 93.61%,  93.89%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: ( 90.48%,  85.71%),  hitEff: (100.00%, 100.00%)

"""


# Extract data lines containing percentages
lines = data.split("\n")
data_lines = [line.strip() for line in lines if "%" in line]

# Extract and print the desired values
for line in data_lines:
    parts = re.findall(r"(\d+\.\d+)%\)", line)
    values = " ".join(parts)
    print(values)
# Out:
# 6.9
# 77.3 7.30 98.61 86.06
# 94.2 13.96 98.56 81.98
# 94.4 13.33 98.31 82.58
# 97.0 0.00 93.96 93.89
# 100.0 0.00 85.71 100.00

# %%
import re

# Multiline string containing the text with multiple data sections
data = """

 Experiment Test of the Hopfield network on the 1th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 1th sample of minibias dataset (Samples_51_to_663_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 1e-06, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 2 mins 17.60 seconds.
Average number of iterations per convergence: 17.8 iterations. 

ID of each event: [355, 39, 933, 70, 640, 201, 125, 314, 946, 957]
Number of hits by event: [583, 484, 462, 340, 383, 503, 426, 603, 599, 541] 
Number of max_neurons by event: [361, 324, 361, 224, 182, 378, 256, 462, 756, 324] 
Hopfield networks runtime by event: ['00:00:19', '00:00:09', '00:00:16', '00:00:06', '00:00:05', '00:00:09', '00:00:08', '00:00:18', '00:00:24', '00:00:19'] 

619 tracks including       25 ghosts (  4.0%). Event average   4.0%
              velo :      512 from      622 ( 82.3%,  83.2%)       25 clones (  4.88%), purity: ( 99.02%,  99.04%),  hitEff: ( 88.68%,  88.72%)
              long :      145 from      153 ( 94.8%,  94.6%)       18 clones ( 12.41%), purity: ( 99.42%,  99.49%),  hitEff: ( 86.96%,  84.62%)
         long>5GeV :       65 from       70 ( 92.9%,  92.2%)        9 clones ( 13.85%), purity: ( 99.53%,  99.60%),  hitEff: ( 85.49%,  83.81%)
      long_strange :        8 from        8 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 97.50%,  97.50%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: (100.00%, 100.00%)
____________________

 Experiment Test of the Hopfield network on the 2th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 2th sample of minibias dataset (Samples_664_to_978_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 0.48, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 10 mins 35.34 seconds.
Average number of iterations per convergence: 27.75 iterations. 

ID of each event: [98, 354, 548, 839, 177, 515, 637, 872, 335, 941]
Number of hits by event: [682, 901, 917, 726, 801, 967, 824, 721, 976, 970] 
Number of max_neurons by event: [528, 840, 676, 650, 552, 750, 650, 380, 961, 810] 
Hopfield networks runtime by event: ['00:00:40', '00:01:19', '00:01:08', '00:00:34', '00:00:46', '00:01:33', '00:00:54', '00:00:28', '00:01:38', '00:01:29'] 

1005 tracks including       69 ghosts (  6.9%). Event average   6.8%
              velo :      808 from     1071 ( 75.4%,  77.3%)       59 clones (  7.30%), purity: ( 98.47%,  98.61%),  hitEff: ( 86.02%,  86.06%)
              long :      265 from      289 ( 91.7%,  94.2%)       37 clones ( 13.96%), purity: ( 98.60%,  98.56%),  hitEff: ( 82.90%,  81.98%)
         long>5GeV :      180 from      194 ( 92.8%,  94.4%)       24 clones ( 13.33%), purity: ( 98.29%,  98.31%),  hitEff: ( 83.65%,  82.58%)
      long_strange :        9 from       11 ( 81.8%,  97.0%)        0 clones (  0.00%), purity: ( 95.97%,  93.96%),  hitEff: ( 93.61%,  93.89%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: ( 90.48%,  85.71%),  hitEff: (100.00%, 100.00%)
____________________
"""

# %%
# Split the data into sections based on the separator
sections = data.split("____________________")

# Loop through each section, extract and print the desired values
for section in sections:
    # Extract data lines containing percentages
    lines = section.split("\n")
    data_lines = [line.strip() for line in lines if "%" in line]

    # Extract and print the desired values for each section
    for line in data_lines:
        parts = re.findall(r"(\d+\.\d+)%\)", line)
        values = " ".join(parts)
        print(values)
    
    print("\n")  # Separate sections with an empty line
# Out:
# 4.0
# 83.2 4.88 99.04 88.72
# 94.6 12.41 99.49 84.62
# 92.2 13.85 99.60 83.81
# 100.0 0.00 100.00 97.50
# 100.0 0.00 100.00 100.00
#
#
# 6.9
# 77.3 7.30 98.61 86.06
# 94.2 13.96 98.56 81.98
# 94.4 13.33 98.31 82.58
# 97.0 0.00 93.96 93.89
# 100.0 0.00 85.71 100.00

# %%
import re

# Multiline string containing the text with multiple data sections
data =  """

 Experiment Test of the Hopfield network on the 1th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 1th sample of minibias dataset (Samples_51_to_663_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 1e-06, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 2 mins 17.60 seconds.
Average number of iterations per convergence: 17.8 iterations. 

ID of each event: [355, 39, 933, 70, 640, 201, 125, 314, 946, 957]
Number of hits by event: [583, 484, 462, 340, 383, 503, 426, 603, 599, 541] 
Number of max_neurons by event: [361, 324, 361, 224, 182, 378, 256, 462, 756, 324] 
Hopfield networks runtime by event: ['00:00:19', '00:00:09', '00:00:16', '00:00:06', '00:00:05', '00:00:09', '00:00:08', '00:00:18', '00:00:24', '00:00:19'] 

619 tracks including       25 ghosts (  4.0%). Event average   4.0%
              velo :      512 from      622 ( 82.3%,  83.2%)       25 clones (  4.88%), purity: ( 99.02%,  99.04%),  hitEff: ( 88.68%,  88.72%)
              long :      145 from      153 ( 94.8%,  94.6%)       18 clones ( 12.41%), purity: ( 99.42%,  99.49%),  hitEff: ( 86.96%,  84.62%)
         long>5GeV :       65 from       70 ( 92.9%,  92.2%)        9 clones ( 13.85%), purity: ( 99.53%,  99.60%),  hitEff: ( 85.49%,  83.81%)
      long_strange :        8 from        8 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 97.50%,  97.50%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: (100.00%, 100.00%)
____________________

 Experiment Test of the Hopfield network on the 2th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 2th sample of minibias dataset (Samples_664_to_978_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 0.48, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 10 mins 35.34 seconds.
Average number of iterations per convergence: 27.75 iterations. 

ID of each event: [98, 354, 548, 839, 177, 515, 637, 872, 335, 941]
Number of hits by event: [682, 901, 917, 726, 801, 967, 824, 721, 976, 970] 
Number of max_neurons by event: [528, 840, 676, 650, 552, 750, 650, 380, 961, 810] 
Hopfield networks runtime by event: ['00:00:40', '00:01:19', '00:01:08', '00:00:34', '00:00:46', '00:01:33', '00:00:54', '00:00:28', '00:01:38', '00:01:29'] 

1005 tracks including       69 ghosts (  6.9%). Event average   6.8%
              velo :      808 from     1071 ( 75.4%,  77.3%)       59 clones (  7.30%), purity: ( 98.47%,  98.61%),  hitEff: ( 86.02%,  86.06%)
              long :      265 from      289 ( 91.7%,  94.2%)       37 clones ( 13.96%), purity: ( 98.60%,  98.56%),  hitEff: ( 82.90%,  81.98%)
         long>5GeV :      180 from      194 ( 92.8%,  94.4%)       24 clones ( 13.33%), purity: ( 98.29%,  98.31%),  hitEff: ( 83.65%,  82.58%)
      long_strange :        9 from       11 ( 81.8%,  97.0%)        0 clones (  0.00%), purity: ( 95.97%,  93.96%),  hitEff: ( 93.61%,  93.89%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: ( 90.48%,  85.71%),  hitEff: (100.00%, 100.00%)
____________________
"""
# Split the data into sections based on the separator
sections = data.split("____________________")

# Define regular expression to match lines containing percentages
pattern = re.compile(r"(\d+\.\d+)%\)")

# Loop through each section, extract and print the desired values
for section in sections:
    # Extract data lines containing percentages
    lines = section.split("\n")
    data_lines = [line.strip() for line in lines if "%" in line]

    # Extract and print the desired values for each section
    for line in data_lines:
        parts = pattern.findall(line)
        if parts:
            print(parts)

    print("\n")  # Separate sections with an empty line
# Out:
# ['4.0']
# ['83.2', '4.88', '99.04', '88.72']
# ['94.6', '12.41', '99.49', '84.62']
# ['92.2', '13.85', '99.60', '83.81']
# ['100.0', '0.00', '100.00', '97.50']
# ['100.0', '0.00', '100.00', '100.00']
#
#
# ['6.9']
# ['77.3', '7.30', '98.61', '86.06']
# ['94.2', '13.96', '98.56', '81.98']
# ['94.4', '13.33', '98.31', '82.58']
# ['97.0', '0.00', '93.96', '93.89']
# ['100.0', '0.00', '85.71', '100.00']

# %%
# Split the data into sections based on the separator
data =""" 

 Experiment Test of the Hopfield network on the 1th sample bsphiphi dataset

Upgraded network - Best Configuration test on 10 events from the 1th sample of bsphiphi dataset (Samples_336_to_1118_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 1e-06, 'T_decay': <function <lambda> at 0x7f4d49403550>, 'B_decay': <function <lambda> at 0x7f4d494035e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 12 mins 57.24 seconds.
Average number of iterations per convergence: 21.5 iterations. 

ID of each event: [988, 721, 705, 55, 413, 515, 353, 216, 752, 753]
Number of hits by event: [1116, 957, 1062, 751, 459, 819, 706, 1038, 687, 747] 
Number of max_neurons by event: [1640, 728, 858, 550, 304, 899, 600, 957, 638, 600] 
Hopfield networks runtime by event: ['00:02:59', '00:01:31', '00:02:02', '00:00:53', '00:00:10', '00:01:15', '00:00:52', '00:01:55', '00:00:35', '00:00:40'] 

981 tracks including       50 ghosts (  5.1%). Event average   4.9%
              velo :      780 from     1005 ( 77.6%,  77.5%)       53 clones (  6.79%), purity: ( 98.71%,  98.75%),  hitEff: ( 86.91%,  86.70%)
              long :      306 from      325 ( 94.2%,  94.4%)       30 clones (  9.80%), purity: ( 98.63%,  98.71%),  hitEff: ( 85.65%,  84.81%)
         long>5GeV :      193 from      203 ( 95.1%,  95.8%)       18 clones (  9.33%), purity: ( 98.15%,  98.21%),  hitEff: ( 85.95%,  85.64%)
      long_strange :       14 from       16 ( 87.5%,  83.9%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 91.93%,  90.04%)
 long_strange>5GeV :        3 from        4 ( 75.0%,  87.5%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 93.75%,  91.67%)
        long_fromb :       39 from       44 ( 88.6%,  89.8%)        6 clones ( 15.38%), purity: ( 97.30%,  97.88%),  hitEff: ( 80.44%,  81.12%)
____________________

 Experiment Test of the Hopfield network on the 2th sample bsphiphi dataset

Upgraded network - Best Configuration test on 10 events from the 2th sample of bsphiphi dataset (Samples_1130_to_1450_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 0.92, 'T_decay': <function <lambda> at 0x7f4d49403550>, 'B_decay': <function <lambda> at 0x7f4d494035e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 42 mins 33.86 seconds.
Average number of iterations per convergence: 35.0 iterations. 

ID of each event: [484, 580, 548, 17, 694, 665, 727, 1, 314, 710]
Number of hits by event: [1425, 1396, 1366, 1318, 1450, 1184, 1166, 1156, 1443, 1130] 
Number of max_neurons by event: [1404, 1292, 1978, 1122, 2116, 1155, 1089, 1560, 1444, 1023] 
Hopfield networks runtime by event: ['00:05:00', '00:04:43', '00:05:26', '00:03:58', '00:06:27', '00:03:38', '00:02:38', '00:02:42', '00:05:11', '00:02:46'] 

1491 tracks including       85 ghosts (  5.7%). Event average   5.8%
              velo :     1159 from     1472 ( 78.7%,  77.1%)      117 clones ( 10.09%), purity: ( 98.68%,  98.69%),  hitEff: ( 81.45%,  81.22%)
              long :      456 from      491 ( 92.9%,  91.8%)       70 clones ( 15.35%), purity: ( 98.67%,  98.67%),  hitEff: ( 78.58%,  78.05%)
         long>5GeV :      308 from      321 ( 96.0%,  95.3%)       55 clones ( 17.86%), purity: ( 98.32%,  98.31%),  hitEff: ( 76.60%,  76.43%)
      long_strange :       22 from       26 ( 84.6%,  93.6%)        5 clones ( 22.73%), purity: ( 99.72%,  99.86%),  hitEff: ( 78.54%,  73.93%)
 long_strange>5GeV :       12 from       14 ( 85.7%,  90.6%)        1 clones (  8.33%), purity: (100.00%, 100.00%),  hitEff: ( 86.57%,  85.36%)
        long_fromb :       61 from       64 ( 95.3%,  92.7%)        8 clones ( 13.11%), purity: ( 98.66%,  98.76%),  hitEff: ( 78.30%,  78.71%)
   long_fromb>5GeV :       52 from       54 ( 96.3%,  92.4%)        8 clones ( 15.38%), purity: ( 98.46%,  98.45%),  hitEff: ( 78.05%,  77.27%)
____________________
"""


sections = data.split("____________________")

# Define regular expression to match lines containing percentages
pattern = re.compile(r"(\d+\.\d+)%\)")

# Loop through each section, extract and print the desired values
for section in sections:
    # Extract data lines containing percentages
    lines = section.split("\n")
    data_lines = [line.strip() for line in lines if "%" in line]

    # Extract and print the desired values for each section
    for line in data_lines:
        parts = pattern.findall(line)
        if parts:
            print(parts)

    print("\n")  # Separate sections with an empty line
# Out:
# ['5.1']
# ['77.5', '6.79', '98.75', '86.70']
# ['94.4', '9.80', '98.71', '84.81']
# ['95.8', '9.33', '98.21', '85.64']
# ['83.9', '0.00', '100.00', '90.04']
# ['87.5', '0.00', '100.00', '91.67']
# ['89.8', '15.38', '97.88', '81.12']
#
#
# ['5.7']
# ['77.1', '10.09', '98.69', '81.22']
# ['91.8', '15.35', '98.67', '78.05']
# ['95.3', '17.86', '98.31', '76.43']
# ['93.6', '22.73', '99.86', '73.93']
# ['90.6', '8.33', '100.00', '85.36']
# ['92.7', '13.11', '98.76', '78.71']
# ['92.4', '15.38', '98.45', '77.27']

# %%
data = [
    ['5.1'],
    ['77.5', '6.79', '98.75', '86.70'],
    ['94.4', '9.80', '98.71', '84.81'],
    ['95.8', '9.33', '98.21', '85.64'],
    ['83.9', '0.00', '100.00', '90.04'],
    ['87.5', '0.00', '100.00', '91.67'],
    ['89.8', '15.38', '97.88', '81.12'],
    ['5.7'],
    ['77.1', '10.09', '98.69', '81.22'],
    ['91.8', '15.35', '98.67', '78.05'],
    ['95.3', '17.86', '98.31', '76.43'],
    ['93.6', '22.73', '99.86', '73.93'],
    ['90.6', '8.33', '100.00', '85.36'],
    ['92.7', '13.11', '98.76', '78.71'],
    ['92.4', '15.38', '98.45', '77.27']
]

# Initialize variables to keep track of the current metric and its data
current_metric = None
metric_data = []

# Initialize a dictionary to store the tables
tables = {}

for entry in data:
    if len(entry) == 1:
        # This is a new metric type
        if current_metric is not None:
            # Save the current metric data to the tables dictionary
            tables[current_metric] = metric_data
        current_metric = entry[0]
        metric_data = []
    else:
        # This is data for the current metric
        metric_data.append(entry)

# Save the last metric data to the tables dictionary
if current_metric is not None:
    tables[current_metric] = metric_data

# Print or process the separate tables
for metric, data in tables.items():
    print(f"Table for metric {metric}:")
    for row in data:
        print(row)
    print("\n")
# Out:
# Table for metric 5.1:
# ['77.5', '6.79', '98.75', '86.70']
# ['94.4', '9.80', '98.71', '84.81']
# ['95.8', '9.33', '98.21', '85.64']
# ['83.9', '0.00', '100.00', '90.04']
# ['87.5', '0.00', '100.00', '91.67']
# ['89.8', '15.38', '97.88', '81.12']
#
#
# Table for metric 5.7:
# ['77.1', '10.09', '98.69', '81.22']
# ['91.8', '15.35', '98.67', '78.05']
# ['95.3', '17.86', '98.31', '76.43']
# ['93.6', '22.73', '99.86', '73.93']
# ['90.6', '8.33', '100.00', '85.36']
# ['92.7', '13.11', '98.76', '78.71']
# ['92.4', '15.38', '98.45', '77.27']

# %%
import re

# Multiline string containing the text with multiple data sections
data =  """

 Experiment Test of the Hopfield network on the 1th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 1th sample of minibias dataset (Samples_51_to_663_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 1e-06, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 2 mins 17.60 seconds.
Average number of iterations per convergence: 17.8 iterations. 

ID of each event: [355, 39, 933, 70, 640, 201, 125, 314, 946, 957]
Number of hits by event: [583, 484, 462, 340, 383, 503, 426, 603, 599, 541] 
Number of max_neurons by event: [361, 324, 361, 224, 182, 378, 256, 462, 756, 324] 
Hopfield networks runtime by event: ['00:00:19', '00:00:09', '00:00:16', '00:00:06', '00:00:05', '00:00:09', '00:00:08', '00:00:18', '00:00:24', '00:00:19'] 

619 tracks including       25 ghosts (  4.0%). Event average   4.0%
              velo :      512 from      622 ( 82.3%,  83.2%)       25 clones (  4.88%), purity: ( 99.02%,  99.04%),  hitEff: ( 88.68%,  88.72%)
              long :      145 from      153 ( 94.8%,  94.6%)       18 clones ( 12.41%), purity: ( 99.42%,  99.49%),  hitEff: ( 86.96%,  84.62%)
         long>5GeV :       65 from       70 ( 92.9%,  92.2%)        9 clones ( 13.85%), purity: ( 99.53%,  99.60%),  hitEff: ( 85.49%,  83.81%)
      long_strange :        8 from        8 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: ( 97.50%,  97.50%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: (100.00%, 100.00%),  hitEff: (100.00%, 100.00%)
____________________

 Experiment Test of the Hopfield network on the 2th sample minibias dataset

Upgraded network - Best Configuration test on 10 events from the 2th sample of minibias dataset (Samples_664_to_978_hits)
Number of events: 10
Parameters: {'random_neuron_init': True, 'binary_states': False, 'ALPHA': 1, 'BETA': 10, 'GAMMA': 10, 'narrowness': 200, 'constant_factor': 0.9, 'monotone_constant_factor': 0.9, 'T': 1e-08, 'B': 0.48, 'T_decay': <function <lambda> at 0x7f60e98f5550>, 'B_decay': <function <lambda> at 0x7f60e98f55e0>, 'decay_off': False, 'randomized_updates': True, 'fully_randomized_updates': False, 'maxActivation': True, 'THRESHOLD': 0.2, 'convergence_threshold': 5e-08, 'bootstrap_iters': 10, 'bootstrap_method': 'below_mean', 'smart': True, 'only_weight': False, 'max_activation': False, 'pruning_tr': 0.05}
Total time to run all the Hopfield Networks: 10 mins 35.34 seconds.
Average number of iterations per convergence: 27.75 iterations. 

ID of each event: [98, 354, 548, 839, 177, 515, 637, 872, 335, 941]
Number of hits by event: [682, 901, 917, 726, 801, 967, 824, 721, 976, 970] 
Number of max_neurons by event: [528, 840, 676, 650, 552, 750, 650, 380, 961, 810] 
Hopfield networks runtime by event: ['00:00:40', '00:01:19', '00:01:08', '00:00:34', '00:00:46', '00:01:33', '00:00:54', '00:00:28', '00:01:38', '00:01:29'] 

1005 tracks including       69 ghosts (  6.9%). Event average   6.8%
              velo :      808 from     1071 ( 75.4%,  77.3%)       59 clones (  7.30%), purity: ( 98.47%,  98.61%),  hitEff: ( 86.02%,  86.06%)
              long :      265 from      289 ( 91.7%,  94.2%)       37 clones ( 13.96%), purity: ( 98.60%,  98.56%),  hitEff: ( 82.90%,  81.98%)
         long>5GeV :      180 from      194 ( 92.8%,  94.4%)       24 clones ( 13.33%), purity: ( 98.29%,  98.31%),  hitEff: ( 83.65%,  82.58%)
      long_strange :        9 from       11 ( 81.8%,  97.0%)        0 clones (  0.00%), purity: ( 95.97%,  93.96%),  hitEff: ( 93.61%,  93.89%)
 long_strange>5GeV :        3 from        3 (100.0%, 100.0%)        0 clones (  0.00%), purity: ( 90.48%,  85.71%),  hitEff: (100.00%, 100.00%)
____________________
"""

# Split the data into sections based on the separator
sections = data.split("____________________")

# Define regular expression to match lines containing percentages
pattern = re.compile(r"(\d+\.\d+)%\)")

# Loop through each section, extract and print the desired values
for idx, section in enumerate(sections):
    # Add section index to the first line of each section
    section_lines = section.strip().split('\n')
    if section_lines:
        section_index = f"{idx + 1}"
        print(section_index)
        
        # Extract and print the desired values for each section
        for line in section_lines:
            parts = pattern.findall(line)
            if parts:
                print(parts)

        print("\n")  # Separate sections with an empty line
# Out:
# 1
# ['4.0']
# ['83.2', '4.88', '99.04', '88.72']
# ['94.6', '12.41', '99.49', '84.62']
# ['92.2', '13.85', '99.60', '83.81']
# ['100.0', '0.00', '100.00', '97.50']
# ['100.0', '0.00', '100.00', '100.00']
#
#
# 2
# ['6.9']
# ['77.3', '7.30', '98.61', '86.06']
# ['94.2', '13.96', '98.56', '81.98']
# ['94.4', '13.33', '98.31', '82.58']
# ['97.0', '0.00', '93.96', '93.89']
# ['100.0', '0.00', '85.71', '100.00']
#
#
# 3
